# %% [markdown]
# # Problem 4: distance-3 surface code

# %%
# There's a dependency in Bloqade that (currently)
# spits out some warnings you don't need to worry about.
import warnings
warnings.filterwarnings("ignore")

from bloqade.qasm2.rewrite.native_gates import RydbergGateSetRewriteRule
from kirin.rewrite import Walk
from bloqade import qasm2
from bloqade.qasm2.parse.lowering import QASM2
from bloqade.qasm2.passes import QASM2Py
from bloqade.qasm2.emit import QASM2 # the QASM2 target
from bloqade.qasm2.parse import pprint # the QASM2 pretty printer

from kirin import ir
from qiskit import QuantumCircuit

from bloqade.qasm2.rewrite.native_gates import RydbergGateSetRewriteRule
from kirin import ir
from kirin.rewrite import Walk
from bloqade.qasm2.passes import UOpToParallel, QASM2Fold

from bloqade.qasm2.emit import QASM2 # the QASM2 target
from bloqade.qasm2.parse import pprint # the QASM2 pretty printer

target = QASM2(allow_parallel=True)

import numpy as np


@ir.dialect_group(qasm2.extended)
def extended_opt(self):
    native_rewrite = Walk(RydbergGateSetRewriteRule(self)) # use Kirin's functionality to walk code line by line while applying neutral-atom gate decomposition as defined in Bloqade
    parallelize_pass = UOpToParallel(self) # review the code and apply parallelization using a heuristic
    agg_fold = QASM2Fold(self) # supports parallelization by unfolding loops to search for parallelization opportunities

    # here we define our new compiler pass
    def run_pass(
        kernel: ir.Method,
        *,
        fold: bool = True,
        typeinfer: bool = True,
        parallelize: bool = False,
    ):
        assert qasm2.extended.run_pass is not None
        qasm2.extended.run_pass(kernel, fold=fold, typeinfer=typeinfer) # apply the original run_pass to the lowered kernel
        native_rewrite.rewrite(kernel.code) # decompose all gates in the circuit to neutral atom gate set

        # here goes our parallelization optimizer; the order of the commands here matters!
        if parallelize:
            agg_fold.fixpoint(kernel)
            parallelize_pass(kernel)

    return run_pass


# helper to go from Method → Qiskit
def method_to_qiskit(method: ir.Method, *,parallelize: bool = True) -> QuantumCircuit:
    # run extended pass in case forgot
    extended_opt.run_pass(method, parallelize=parallelize)
    # emit OpenQASM2 text
    qasm = QASM2().emit_str(method)
    # parse into a Qiskit circuit
    return QuantumCircuit.from_qasm_str(qasm)

def method_to_qiskit_noparallel(method: ir.Method, *,parallelize: bool = True) -> QuantumCircuit:
    # emit OpenQASM2 text
    qasm = QASM2().emit_str(method)
    # parse into a Qiskit circuit
    return QuantumCircuit.from_qasm_str(qasm)

def print_gate_counts(ast): 
    """
    Print the counts of parallel and non parallel in the given AST,
    Distinguishing between single U and CZ gates and their parallelized versions.
    """
    test_string = qasm2.parse.spprint(ast)

    parallel_cz_count = test_string.count("parallel.CZ")
    parallel_u_count = test_string.count("parallel.U")
    u_count = test_string.count("U")  # To avoid counting "parallel.U"
    cz_count = test_string.count("cz")

    print(f"parallel CZ: {parallel_cz_count}")
    print(f"parallel U: {parallel_u_count}")
    print(f"other U: {u_count - parallel_u_count}")
    print(f"other CZ: {cz_count}")

# %% [markdown]
# ## Reference circuit

# %%
def basemethod(parallelize: bool = False):

    @extended_opt(parallelize=parallelize)
    def basemethod_program():
        q = qasm2.qreg(17)
        qasm2.h(q[4])
        qasm2.h(q[6])
        qasm2.h(q[10])
        qasm2.h(q[12])
        qasm2.cx(q[3],q[0])
        qasm2.cx(q[4],q[7])
        qasm2.cx(q[10],q[14])
        qasm2.cx(q[6],q[9])
        qasm2.cx(q[15],q[11])
        qasm2.cx(q[8],q[5])
        qasm2.cx(q[4],q[1])
        qasm2.cx(q[7],q[5])
        qasm2.cx(q[10],q[8])
        qasm2.cx(q[14],q[11])
        qasm2.cx(q[6],q[3])
        qasm2.cx(q[2],q[0])
        qasm2.cx(q[2],q[5])
        qasm2.cx(q[6],q[8])
        qasm2.cx(q[10],q[13])
        qasm2.cx(q[14],q[16])
        qasm2.cx(q[9],q[11])
        qasm2.cx(q[12],q[15])
        qasm2.cx(q[10],q[7])
        qasm2.cx(q[6],q[2])
        qasm2.cx(q[13],q[16])
        qasm2.cx(q[12],q[9])
        qasm2.cx(q[1],q[5])
        qasm2.cx(q[8],q[11])
        qasm2.h(q[4])
        qasm2.h(q[6])
        qasm2.h(q[10])
        qasm2.h(q[12])
        return q

    return basemethod_program

# %%
print_gate_counts(target.emit(basemethod(parallelize=True)))
# Out:
# parallel CZ: 7
# parallel U: 30
# other U: 15
# other CZ: 4

# %%
qasm2.parse.pprint(target.emit(basemethod(parallelize=True)))
# Out:
# KIRIN {func,lowering.call,lowering.func,py.ilist,qasm2.core,qasm2.expr,qasm2.indexing,qasm2.parallel,qasm2.uop,scf};
# include "qelib1.inc";
# qreg Qbits[17];
# parallel.U(1.5707963267949, 0.0, 3.14159265358979) {
#   Qbits[4];
#   Qbits[6];
#   Qbits[10];
#   Qbits[12];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[0];
#   Qbits[7];
#   Qbits[14];
#   Qbits[9];
#   Qbits[11];
#   Qbits[5];
#   Qbits[1];
#   Qbits[13];
#   Qbits[16];
# }
# parallel.CZ {
#   Qbits[3], Qbits[0];
#   Qbits[4], Qbits[7];
#   Qbits[10], Qbits[14];
#   Qbits[6], Qbits[9];
#   Qbits[15], Qbits[11];
#   Qbits[8], Qbits[5];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[0];
#   Qbits[7];
#   Qbits[14];
#   Qbits[9];
#   Qbits[11];
#   Qbits[5];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[3];
#   Qbits[4];
#   Qbits[10];
#   Qbits[6];
#   Qbits[15];
#   Qbits[8];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[0];
#   Qbits[7];
#   Qbits[14];
#   Qbits[9];
#   Qbits[11];
#   Qbits[5];
# }
# cz Qbits[4], Qbits[1];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) Qbits[1];
# U(0.0, 0.0, 3.14159265358979) Qbits[4];
# U(0.0, 0.0, 6.28318530717958) Qbits[1];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[5];
#   Qbits[11];
#   Qbits[0];
# }
# parallel.CZ {
#   Qbits[7], Qbits[5];
#   Qbits[14], Qbits[11];
#   Qbits[2], Qbits[0];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[5];
#   Qbits[11];
#   Qbits[0];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[7];
#   Qbits[14];
#   Qbits[2];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[5];
#   Qbits[11];
#   Qbits[0];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[8];
#   Qbits[3];
#   Qbits[15];
# }
# parallel.CZ {
#   Qbits[10], Qbits[8];
#   Qbits[6], Qbits[3];
#   Qbits[12], Qbits[15];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[8];
#   Qbits[3];
#   Qbits[15];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[10];
#   Qbits[6];
#   Qbits[12];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[8];
#   Qbits[3];
#   Qbits[15];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[5];
#   Qbits[11];
# }
# parallel.CZ {
#   Qbits[2], Qbits[5];
#   Qbits[9], Qbits[11];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[5];
#   Qbits[11];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[2];
#   Qbits[9];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[5];
#   Qbits[11];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[8];
#   Qbits[7];
# }
# parallel.CZ {
#   Qbits[6], Qbits[8];
#   Qbits[10], Qbits[7];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[8];
#   Qbits[7];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[6];
#   Qbits[10];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[8];
#   Qbits[7];
# }
# cz Qbits[10], Qbits[13];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) Qbits[13];
# U(0.0, 0.0, 3.14159265358979) Qbits[10];
# U(0.0, 0.0, 6.28318530717958) Qbits[13];
# cz Qbits[14], Qbits[16];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) Qbits[16];
# U(0.0, 0.0, 3.14159265358979) Qbits[14];
# U(0.0, 0.0, 6.28318530717958) Qbits[16];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[2];
#   Qbits[9];
# }
# parallel.CZ {
#   Qbits[6], Qbits[2];
#   Qbits[12], Qbits[9];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[2];
#   Qbits[9];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[6];
#   Qbits[12];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[2];
#   Qbits[9];
# }
# U(1.5707963267949, 0.0, 6.28318530717959) Qbits[16];
# cz Qbits[13], Qbits[16];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) Qbits[16];
# U(0.0, 0.0, 3.14159265358979) Qbits[13];
# U(0.0, 0.0, 6.28318530717958) Qbits[16];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   Qbits[5];
#   Qbits[11];
# }
# parallel.CZ {
#   Qbits[1], Qbits[5];
#   Qbits[8], Qbits[11];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   Qbits[5];
#   Qbits[11];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   Qbits[1];
#   Qbits[8];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   Qbits[5];
#   Qbits[11];
# }
# U(1.5707963267949, 0.0, 3.14159265358979) Qbits[4];
# parallel.U(1.5707963267949, 0.0, 3.14159265358979) {
#   Qbits[6];
#   Qbits[12];
# }
# U(1.5707963267949, 0.0, 3.14159265358979) Qbits[10];

# %%
qc = method_to_qiskit(basemethod(parallelize=True))
#print(qc.draw(output="text"))
fig = qc.draw(output="mpl", fold=120, scale=0.7)
display(fig)   # in a Jupyter notebook

# %% [markdown]
# ## Optimized circuit

# %%
def method(parallelize: bool = False):

    @extended_opt(parallelize=parallelize)
    def method_program():
        q = qasm2.qreg(17)
        qasm2.h(q[4])
        qasm2.h(q[6])
        qasm2.h(q[10])
        qasm2.h(q[12])
        qasm2.cx(q[3],q[0])
        qasm2.cx(q[6],q[9])
        qasm2.cx(q[10],q[14])
        qasm2.cx(q[4],q[7])
        qasm2.cx(q[8],q[5])
        qasm2.cx(q[15],q[11])
        qasm2.cx(q[4],q[1])
        qasm2.cx(q[7],q[5])
        qasm2.cx(q[10],q[8])
        qasm2.cx(q[14],q[11])
        qasm2.cx(q[2],q[0])
        qasm2.cx(q[6],q[3])
        qasm2.cx(q[12],q[15])
        qasm2.cx(q[2],q[5])
        qasm2.cx(q[6],q[8])
        qasm2.cx(q[10],q[13])
        qasm2.cx(q[14],q[16])
        qasm2.cx(q[9],q[11])
        qasm2.cx(q[10],q[7])
        qasm2.cx(q[6],q[2])
        qasm2.cx(q[12],q[9])
        qasm2.cx(q[13],q[16])
        qasm2.cx(q[1],q[5])
        qasm2.cx(q[8],q[11])
        qasm2.h(q[4])
        qasm2.h(q[6])
        qasm2.h(q[10])
        qasm2.h(q[12])
        return q

    return method_program

# %%
print_gate_counts(target.emit(method(parallelize=True)))
# Out:
# parallel CZ: 7
# parallel U: 30
# other U: 15
# other CZ: 4

# %%
qasm2.parse.pprint(target.emit(method(parallelize=True)))
# Out:
# KIRIN {func,lowering.call,lowering.func,py.ilist,qasm2.core,qasm2.expr,qasm2.indexing,qasm2.parallel,qasm2.uop,scf};
# include "qelib1.inc";
# qreg q[17];
# parallel.U(1.5707963267949, 0.0, 3.14159265358979) {
#   q[4];
#   q[6];
#   q[10];
#   q[12];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[0];
#   q[9];
#   q[14];
#   q[7];
#   q[5];
#   q[11];
#   q[1];
#   q[13];
#   q[16];
# }
# parallel.CZ {
#   q[3], q[0];
#   q[6], q[9];
#   q[10], q[14];
#   q[4], q[7];
#   q[8], q[5];
#   q[15], q[11];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[0];
#   q[9];
#   q[14];
#   q[7];
#   q[5];
#   q[11];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[3];
#   q[6];
#   q[10];
#   q[4];
#   q[8];
#   q[15];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[0];
#   q[9];
#   q[14];
#   q[7];
#   q[5];
#   q[11];
# }
# cz q[4], q[1];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) q[1];
# U(0.0, 0.0, 3.14159265358979) q[4];
# U(0.0, 0.0, 6.28318530717958) q[1];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[5];
#   q[11];
#   q[0];
# }
# parallel.CZ {
#   q[7], q[5];
#   q[14], q[11];
#   q[2], q[0];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[5];
#   q[11];
#   q[0];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[7];
#   q[14];
#   q[2];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[5];
#   q[11];
#   q[0];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[8];
#   q[3];
#   q[15];
# }
# parallel.CZ {
#   q[10], q[8];
#   q[6], q[3];
#   q[12], q[15];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[8];
#   q[3];
#   q[15];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[10];
#   q[6];
#   q[12];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[8];
#   q[3];
#   q[15];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[5];
#   q[11];
# }
# parallel.CZ {
#   q[2], q[5];
#   q[9], q[11];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[5];
#   q[11];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[2];
#   q[9];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[5];
#   q[11];
# }
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[8];
#   q[7];
# }
# parallel.CZ {
#   q[6], q[8];
#   q[10], q[7];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[8];
#   q[7];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[6];
#   q[10];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[8];
#   q[7];
# }
# cz q[10], q[13];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) q[13];
# U(0.0, 0.0, 3.14159265358979) q[10];
# U(0.0, 0.0, 6.28318530717958) q[13];
# cz q[14], q[16];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) q[16];
# U(0.0, 0.0, 3.14159265358979) q[14];
# U(0.0, 0.0, 6.28318530717958) q[16];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[2];
#   q[9];
# }
# parallel.CZ {
#   q[6], q[2];
#   q[12], q[9];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[2];
#   q[9];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[6];
#   q[12];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[2];
#   q[9];
# }
# U(1.5707963267949, 0.0, 6.28318530717959) q[16];
# cz q[13], q[16];
# U(1.5707963267949, 3.14159265358979, 3.14159265358979) q[16];
# U(0.0, 0.0, 3.14159265358979) q[13];
# U(0.0, 0.0, 6.28318530717958) q[16];
# parallel.U(1.5707963267949, 0.0, 6.28318530717959) {
#   q[5];
#   q[11];
# }
# parallel.CZ {
#   q[1], q[5];
#   q[8], q[11];
# }
# parallel.U(1.5707963267949, 3.14159265358979, 3.14159265358979) {
#   q[5];
#   q[11];
# }
# parallel.U(0.0, 0.0, 3.14159265358979) {
#   q[1];
#   q[8];
# }
# parallel.U(0.0, 0.0, 6.28318530717958) {
#   q[5];
#   q[11];
# }
# U(1.5707963267949, 0.0, 3.14159265358979) q[4];
# parallel.U(1.5707963267949, 0.0, 3.14159265358979) {
#   q[6];
#   q[12];
# }
# U(1.5707963267949, 0.0, 3.14159265358979) q[10];

# %%
qc = method_to_qiskit(method(parallelize=True))
#print(qc.draw(output="text"))
fig = qc.draw(output="mpl", fold=120, scale=0.7)
display(fig)   # in a Jupyter notebook

# %% [markdown]
# ## Simulate

# %%
from bloqade.pyqrack import PyQrack
from collections import Counter
from qiskit.quantum_info import Statevector, Operator

basekernel = basemethod(parallelize=True)
kernel = method(parallelize=True)

device = PyQrack(dynamic_qubits=True, pyqrack_options={"isBinaryDecisionTree": False})
basereg = device.run(basekernel)
reg = device.run(kernel)

# %%
qbit = basereg[0]
basefinalstate = Statevector(qbit.sim_reg.out_ket())
display(basefinalstate.draw("latex"))
# Out:
# $$(0.0053759534 + 0.0622683167 i) |00000000000000000\rangle+(-2.6 \cdot 10^{-9} - 6.0 \cdot 10^{-10} i) |00000000000000010\rangle+(-2.5 \cdot 10^{-9} + 4.0 \cdot 10^{-10} i) |00000000000000100\rangle+(-2.6 \cdot 10^{-9} - 3.0 \cdot 10^{-10} i) |00000000000001000\rangle+(0.0053759534 + 0.0622683167 i) |00000000000010000\rangle+(2.6 \cdot 10^{-9} + 6.0 \cdot 10^{-10} i) |00000000000010010\rangle + \ldots +(5.0 \cdot 10^{-9} - 3.1 \cdot 10^{-9} i) |11111011101010010\rangle+(-3.8 \cdot 10^{-9} + 1.6 \cdot 10^{-9} i) |11111011110000000\rangle+(-3.8 \cdot 10^{-9} + 1.6 \cdot 10^{-9} i) |11111011110010000\rangle+(-3.8 \cdot 10^{-9} + 1.6 \cdot 10^{-9} i) |11111011111000000\rangle+(-3.8 \cdot 10^{-9} + 1.6 \cdot 10^{-9} i) |11111011111010000\rangle$$

# %%
qbit = reg[0]
finalstate = Statevector(qbit.sim_reg.out_ket())
display(finalstate.draw("latex"))
# Out:
# $$(0.0614705533 - 0.0112967407 i) |00000000000000000\rangle+(-7.0 \cdot 10^{-10} + 2.5 \cdot 10^{-9} i) |00000000000000010\rangle+(1.7 \cdot 10^{-9} + 2.4 \cdot 10^{-9} i) |00000000000000100\rangle+(9.0 \cdot 10^{-10} + 2.5 \cdot 10^{-9} i) |00000000000001000\rangle+(0.0614705533 - 0.0112967407 i) |00000000000010000\rangle+(7.0 \cdot 10^{-10} - 2.5 \cdot 10^{-9} i) |00000000000010010\rangle + \ldots +(-1.9 \cdot 10^{-9} - 5.7 \cdot 10^{-9} i) |11111011101010010\rangle+(1.9 \cdot 10^{-9} + 5.7 \cdot 10^{-9} i) |11111011110000000\rangle+(1.9 \cdot 10^{-9} + 5.7 \cdot 10^{-9} i) |11111011110010000\rangle+(1.9 \cdot 10^{-9} + 5.7 \cdot 10^{-9} i) |11111011111000000\rangle+(1.9 \cdot 10^{-9} + 5.7 \cdot 10^{-9} i) |11111011111010000\rangle$$

# %%
np.abs(finalstate.inner(basefinalstate))
# Out:
# 0.9999986651729279

# %% [markdown]
# Nice!

# %% [markdown]
# ## Now let's add noise

# %% [markdown]
# Unfortunately there is some issue with noise simulations with certain circuits: this is one of them.

# %%
from bloqade.qasm2.passes import NoisePass
from bloqade.noise import native
import numpy as np

# add noise
noise_kernel = kernel.similar()
extended_opt.run_pass(noise_kernel, parallelize=True)
NoisePass(extended_opt)(noise_kernel)

noise_kernel = noise_kernel.similar(extended_opt.add(native))

device = PyQrack(dynamic_qubits=True, pyqrack_options={"isBinaryDecisionTree": False})

Nshots = 100

noisy_states = [r[0].sim_reg.out_ket() for r in device.multi_run(noise_kernel, _shots = Nshots)]

fidelity = 0
for i in range(Nshots):
    fidelity = fidelity + np.abs(np.vdot(noisy_states[i],finalstate))**2

fidelity = fidelity/Nshots
print(fidelity)
# Out:
# ---------------------------------------------------------------------------
# InterpreterError                          Traceback (most recent call last)
# Cell In[54], line 16
#      12 device = PyQrack(dynamic_qubits=True, pyqrack_options={"isBinaryDecisionTree": False})
#      14 Nshots = 100
# ---> 16 noisy_states = [r[0].sim_reg.out_ket() for r in device.multi_run(noise_kernel, _shots = Nshots)]
#      18 fidelity = 0
#      19 for i in range(Nshots):
#
# File ~/.local/lib/python3.10/site-packages/bloqade/pyqrack/target.py:117, in PyQrack.multi_run(self, mt, _shots, *args, **kwargs)
#     115 batched_results = []
#     116 for _ in range(_shots):
# --> 117     batched_results.append(interpreter.run(mt, args, kwargs))
#     119 return batched_results
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/base.py:161, in BaseInterpreter.run(self, mt, args, kwargs)
#     157 except Exception as e:
#     158     # NOTE: insert the interpreter state into the exception
#     159     # so we can print the stack trace
#     160     setattr(e, KIRIN_INTERP_STATE, self.state)
# --> 161     raise e
#     162 finally:
#     163     self._eval_lock = False
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/base.py:156, in BaseInterpreter.run(self, mt, args, kwargs)
#     154 args = self.get_args(mt.arg_names[len(args) + 1 :], args, kwargs)
#     155 try:
# --> 156     _, results = self.run_method(mt, args)
#     157 except Exception as e:
#     158     # NOTE: insert the interpreter state into the exception
#     159     # so we can print the stack trace
#     160     setattr(e, KIRIN_INTERP_STATE, self.state)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/concrete.py:32, in Interpreter.run_method(self, method, args)
#      29 def run_method(
#      30     self, method: Method, args: tuple[Any, ...]
#      31 ) -> tuple[Frame[Any], Any]:
# ---> 32     return self.run_callable(method.code, (method,) + args)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/base.py:228, in BaseInterpreter.run_callable(self, code, args)
#     226 if not body.blocks:
#     227     return self.state.pop_frame(), self.void
# --> 228 results = self.run_callable_region(frame, code, body, args)
#     229 return self.state.pop_frame(), results
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/base.py:246, in BaseInterpreter.run_callable_region(self, frame, code, region, args)
#     231 def run_callable_region(
#     232     self,
#     233     frame: FrameType,
#    (...)
#     236     args: tuple[ValueType, ...],
#     237 ) -> ValueType:
#     238     """A hook defines how to run the callable region given
#     239     the interpreter context. Frame should be pushed before calling
#     240     this method and popped after calling this method.
#    (...)
#     244     to be compatible with the Python convention.
#     245     """
# --> 246     results = self.run_ssacfg_region(frame, region, args)
#     247     if isinstance(results, ReturnValue):
#     248         return results.value
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/concrete.py:40, in Interpreter.run_ssacfg_region(self, frame, region, args)
#      38 succ = Successor(block, *args)
#      39 while succ is not None:
# ---> 40     results = self.run_succ(frame, succ)
#      41     if isinstance(results, Successor):
#      42         succ = results
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/concrete.py:58, in Interpreter.run_succ(self, frame, succ)
#      56     raise FuelExhaustedError("fuel exhausted")
#      57 frame.current_stmt = stmt
# ---> 58 stmt_results = self.eval_stmt(frame, stmt)
#      59 if isinstance(stmt_results, tuple):
#      60     frame.set_values(stmt._results, stmt_results)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/base.py:377, in BaseInterpreter.eval_stmt(self, frame, stmt)
#     375 method = self.lookup_registry(frame, stmt)
#     376 if method is not None:
# --> 377     results = method(self, frame, stmt)
#     378     if self.debug and not isinstance(results, (tuple, SpecialValue)):
#     379         raise InterpreterError(
#     380             f"method must return tuple or SpecialResult, got {results}"
#     381         )
#
# File ~/.local/lib/python3.10/site-packages/kirin/registry.py:25, in StatementImpl.__call__(self, interp, frame, stmt)
#      24 def __call__(self, interp, frame, stmt: "Statement"):
# ---> 25     return self.impl(self.parent, interp, frame, stmt)
#
# File ~/.local/lib/python3.10/site-packages/kirin/dialects/ilist/interp.py:20, in IListInterpreter.new(self, interp, frame, stmt)
#      18 @impl(New)
#      19 def new(self, interp, frame: Frame, stmt: New):
# ---> 20     return (IList(list(frame.get_values(stmt.values)), elem=stmt.elem_type),)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/frame.py:82, in FrameABC.get_values(self, keys)
#      72 def get_values(self, keys: Iterable[SSAValue]) -> tuple[ValueType, ...]:
#      73     """Get the values of the given [`SSAValue`][kirin.ir.SSAValue] keys.
#      74     See also [`get`][kirin.interp.frame.Frame.get].
#      75
#    (...)
#      80         tuple[ValueType, ...]: The values.
#      81     """
# ---> 82     return tuple(self.get(key) for key in keys)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/frame.py:82, in <genexpr>(.0)
#      72 def get_values(self, keys: Iterable[SSAValue]) -> tuple[ValueType, ...]:
#      73     """Get the values of the given [`SSAValue`][kirin.ir.SSAValue] keys.
#      74     See also [`get`][kirin.interp.frame.Frame.get].
#      75
#    (...)
#      80         tuple[ValueType, ...]: The values.
#      81     """
# ---> 82     return tuple(self.get(key) for key in keys)
#
# File ~/.local/lib/python3.10/site-packages/kirin/interp/frame.py:130, in Frame.get(self, key)
#     128         return self.parent.get(key)
#     129     else:
# --> 130         raise err
#     131 else:
#     132     return value
#
# InterpreterError: SSAValue <ResultValue[Qubit] stmt: qreg.get, uses: 21> not found
